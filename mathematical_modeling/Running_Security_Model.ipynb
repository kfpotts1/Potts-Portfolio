# %%
import Security_Model as SM

# %% [markdown]
# # Pre-Check and Regular Passengers, Same Line

# %%
m1 = SM.Model()

# %%
m1.run_single_line(seconds=8000)

# %%
m1.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+-----------+-----------+-------+--------+-------+--------+-------+
# |                                    |   count |      mean |       std |   min |    25% |   50% |    75% |   max |
# |------------------------------------+---------+-----------+-----------+-------+--------+-------+--------+-------|
# | ('attributes', 'num_bins')         |      56 |   2.46429 |   2.19059 |     0 |   1    |   2   |   3    |     9 |
# | ('process_times', 'bin_placement') |      56 |  26.4643  |  28.0499  |     0 |  13    |  21   |  30.75 |   162 |
# | ('process_times', 'body_scanner')  |      56 |  11.9821  |   5.04342 |     4 |  10    |  11   |  13    |    38 |
# | ('process_times', 'doc_check')     |      56 |  10.8036  |   3.62526 |     5 |   7.75 |  11   |  14    |    20 |
# | ('process_times', 'zone_c')        |      56 |  41.2321  |  51.3544  |     0 |  15.75 |  27   |  46.5  |   288 |
# ...

# %%
m1.summary_plots()

# %%
m7 = SM.Model()
m7.run_single_line(seconds=8000)
m7.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+-----------+-----------+-------+-------+-------+-------+-------+
# |                                    |   count |      mean |       std |   min |   25% |   50% |   75% |   max |
# |------------------------------------+---------+-----------+-----------+-------+-------+-------+-------+-------|
# | ('attributes', 'num_bins')         |     151 |   2.51656 |   1.99951 |     0 |   1   |     2 |   4   |    10 |
# | ('process_times', 'bin_placement') |     151 |  30.4106  |  26.8565  |     0 |  10.5 |    24 |  44   |   138 |
# | ('process_times', 'body_scanner')  |     151 |  12.106   |   6.18401 |     4 |   8   |    11 |  12   |    38 |
# | ('process_times', 'doc_check')     |     151 |  10.4371  |   3.66711 |     5 |   7   |    10 |  12   |    20 |
# | ('process_times', 'zone_c')        |     151 |  34.8013  |  32.2937  |     0 |  11.5 |    24 |  55.5 |   160 |
# ...

# %%
m7.summary_plots()

# %%
m8 = SM.Model()
m8.run_single_line(seconds=10000)
m8.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------+
# |                                    |   count |       mean |       std |   min |   25% |   50% |    75% |   max |
# |------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------|
# | ('attributes', 'num_bins')         |     411 |    2.33577 |   1.813   |     0 |   1   |     2 |    3   |    10 |
# | ('process_times', 'bin_placement') |     411 |   29.2141  |  29.0486  |     0 |   9   |    21 |   42   |   220 |
# | ('process_times', 'body_scanner')  |     411 |   11.2993  |   5.23827 |     4 |   8   |    11 |   12   |    38 |
# | ('process_times', 'doc_check')     |     411 |   10.6423  |   3.5901  |     5 |   8   |    11 |   14   |    20 |
# | ('process_times', 'zone_c')        |     411 |   30.0389  |  28.1556  |     0 |  12   |    22 |   42   |   190 |
# ...

# %%
m8.summary_plots()

# %% [markdown]
# # Pre-Check Only Lane

# %%
m3 = SM.Model(force_pre_check=True)

# %% [markdown]
# ### 5000 seconds

# %%
m3.run_single_line(seconds=5000)

# %%
m3.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------+
# |                                    |   count |       mean |       std |   min |   25% |   50% |    75% |   max |
# |------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------|
# | ('attributes', 'num_bins')         |     239 |    2.56485 |   1.43887 |     0 |   2   |     2 |    3   |     8 |
# | ('process_times', 'bin_placement') |     239 |   30.1088  |  23.553   |     0 |  14   |    24 |   40   |   192 |
# | ('process_times', 'body_scanner')  |     239 |   11.7573  |   5.52835 |     4 |   8   |    11 |   13   |    38 |
# | ('process_times', 'doc_check')     |     239 |   10.7155  |   3.58958 |     5 |   8   |    11 |   14   |    20 |
# | ('process_times', 'zone_c')        |     239 |   34.3515  |  27.3977  |     0 |  15   |    28 |   43   |   184 |
# ...

# %%
m3.summary_plots()

# %% [markdown]
# ### Another Run
#
# #### 8000 seconds

# %%
m4 = SM.Model(force_pre_check=True)

# %%
m4.run_single_line(seconds=8000)

# %%
m4.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+------------+------------+-------+--------+-------+--------+-------+
# |                                    |   count |       mean |        std |   min |    25% |   50% |    75% |   max |
# |------------------------------------+---------+------------+------------+-------+--------+-------+--------+-------|
# | ('attributes', 'num_bins')         |     363 |    2.68871 |    1.45259 |     0 |    2   |     3 |    3   |     8 |
# | ('process_times', 'bin_placement') |     363 |   32.6915  |   24.8447  |     0 |   15   |    27 |   44   |   165 |
# | ('process_times', 'body_scanner')  |     363 |   11.6942  |    5.5819  |     4 |    8   |    11 |   12   |    38 |
# | ('process_times', 'doc_check')     |     363 |   10.832   |    3.94112 |     5 |    7   |    11 |   14   |    20 |
# | ('process_times', 'zone_c')        |     363 |   36.9146  |   27.9923  |     0 |   18   |    30 |   48   |   224 |
# ...

# %%
m4.summary_plots()

# %% [markdown]
# # Regular Passengers Only Lane

# %%
m5 = SM.Model(force_pre_check=False)

# %%
m5.run_single_line(seconds=8000)

# %%
m5.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------+
# |                                    |   count |       mean |       std |   min |   25% |   50% |    75% |   max |
# |------------------------------------+---------+------------+-----------+-------+-------+-------+--------+-------|
# | ('attributes', 'num_bins')         |     223 |    2.39013 |   2.15509 |     0 |   1   |     2 |    3   |    10 |
# | ('process_times', 'bin_placement') |     223 |   29.861   |  32.6652  |     0 |   8   |    21 |   42   |   220 |
# | ('process_times', 'body_scanner')  |     223 |   11.5291  |   5.66623 |     4 |   8   |    11 |   12   |    38 |
# | ('process_times', 'doc_check')     |     223 |   10.3722  |   3.58683 |     5 |   7   |    10 |   12   |    20 |
# | ('process_times', 'zone_c')        |     223 |   32.4036  |  33.76    |     0 |  10   |    23 |   45   |   208 |
# ...

# %%
m5.summary_plots()

# %% [markdown]
# ### Another Run
# #### 8000 seconds

# %%
m6 = SM.Model(force_pre_check=False)
m6.run_single_line(seconds=8000)
m6.summary_stats()
# Out:
# SUMMARY STATISTICS:
# +------------------------------------+---------+-----------+-----------+-------+-------+-------+-------+-------+
# |                                    |   count |      mean |       std |   min |   25% |   50% |   75% |   max |
# |------------------------------------+---------+-----------+-----------+-------+-------+-------+-------+-------|
# | ('attributes', 'num_bins')         |       9 |   3       |   2.64575 |     0 |     1 |     3 |     5 |     7 |
# | ('process_times', 'bin_placement') |       9 |  40.1111  |  40.6154  |     0 |    10 |    24 |    70 |   119 |
# | ('process_times', 'body_scanner')  |       9 |  11.3333  |   2.29129 |    10 |    10 |    10 |    12 |    17 |
# | ('process_times', 'doc_check')     |       9 |  10.3333  |   3.1225  |     5 |     8 |    11 |    12 |    14 |
# | ('process_times', 'zone_c')        |       9 |  35.1111  |  40.7107  |     0 |     3 |    16 |    70 |   108 |
# ...

# %%
m6.summary_plots()
